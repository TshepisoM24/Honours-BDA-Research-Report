# %% [markdown]
# # HYPERPARAMETER TUNING

# %%
import os
os.chdir('/content/sample_data')

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.0.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %% [markdown]
# # Apple Stock Data

# %%
import optuna
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch
import torch.nn as nn
import torch.nn.functional as F
from mamba import Mamba, MambaConfig

# Check for CUDA availability
use_cuda = torch.cuda.is_available()
epochs = 100

# Data loading and preprocessing
# Load data
data = pd.read_csv('/content/sample_data/AAPL_Apple_Inc..csv')
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

# Calculate the percentage change in the 'Close' price
data['pct_chg'] = data['Close'].pct_change() * 100

# Drop the first row if needed and reset the index
data = data.iloc[1:].reset_index(drop=True)

# Extract 'Close' and rate of change
close = data.pop('Close').values
ratechg = data['pct_chg'].apply(lambda x: 0.01 * x).values
data.drop(columns=['pct_chg'], inplace=True)
dat = data.iloc[:, 1:].values

# Columns to normalize
cols_to_normalize = ["Open", "High", "Low", "Adj Close", "Volume"]

# Split data into train, validation, and test
n_test = 100  # The full test set remains constant
n_val = 200
train_data = dat[:-(n_test + n_val)]
val_data = dat[-(n_test + n_val):-n_test]
test_data = dat[-n_test:]

# Calculate mean and std using training and validation sets
mean = np.mean(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)
std = np.std(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)

# Normalize train, validation, and test sets
train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std

# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-3:]  # Using the last 3 data points in test for prediction
testy = ratechg[-n_test:][-3:]  # Last 3 rate changes for evaluation

# Define evaluation metric
def evaluation_metric(y_test, y_hat):
    MSE = mean_squared_error(y_test, y_hat)
    RMSE = MSE**0.5
    MAE = mean_absolute_error(y_test, y_hat)
    R2 = r2_score(y_test, y_hat)
    print('%.6f %.6f %.6f %.6f' % (MSE, RMSE, MAE, R2))

# Define model
class Net(nn.Module):
    def __init__(self, in_dim, out_dim, hidden_dim, num_layers):
        super().__init__()
        self.config = MambaConfig(d_model=hidden_dim, n_layers=num_layers)
        self.mamba = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            Mamba(self.config),
            nn.Linear(hidden_dim, out_dim),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.mamba(x)
        return x.flatten()

# Define objective function for Optuna
def objective(trial):
    # Suggest hyperparameters
    lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
    wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
    hidden_dim = trial.suggest_int('hidden_dim', 8, 64)
    num_layers = trial.suggest_int('num_layers', 1, 4)

    # Set up model and optimizer with trial parameters
    clf = Net(len(trainX[0]), 1, hidden_dim, num_layers)
    opt = torch.optim.Adam(clf.parameters(), lr=lr, weight_decay=wd)

    # Move model to GPU if available
    if use_cuda:
        clf = clf.cuda()

    xt = torch.from_numpy(trainX).float().unsqueeze(0)
    xv = torch.from_numpy(valX).float().unsqueeze(0)
    yt = torch.from_numpy(trainy).float()
    yv = torch.from_numpy(valy).float()

    if use_cuda:
        xt, xv, yt, yv = xt.cuda(), xv.cuda(), yt.cuda(), yv.cuda()

    # Training loop with early stopping
    best_val_loss = float("inf")
    patience, wait = 10, 0
    for e in range(epochs):
        clf.train()
        opt.zero_grad()
        z = clf(xt)
        train_loss = F.mse_loss(z, yt)
        train_loss.backward()
        opt.step()

        # Validation
        clf.eval()
        with torch.no_grad():
            val_pred = clf(xv)
            val_loss = F.mse_loss(val_pred, yv)

        # Early stopping
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    return best_val_loss

# Perform hyperparameter optimization
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

# Print best hyperparameters
print("Best hyperparameters:", study.best_params)

# Retrieve best hyperparameters
best_params = study.best_params
best_lr = best_params['lr']
best_wd = best_params['wd']
best_hidden_dim = best_params['hidden_dim']
best_num_layers = best_params['num_layers']
# Out:
# [I 2024-11-10 16:33:07,138] A new study created in memory with name: no-name-5d748fd1-6104-4007-b9ea-5038299a58c6
# <ipython-input-34-26f1bad2278b>:84: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
# <ipython-input-34-26f1bad2278b>:85: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
# [I 2024-11-10 16:33:09,721] Trial 0 finished with value: 0.0028028273954987526 and parameters: {'lr': 7.76598029029617e-05, 'wd': 0.00020462353463830172, 'hidden_dim': 45, 'num_layers': 3}. Best is trial 0 with value: 0.0028028273954987526.
# [I 2024-11-10 16:33:10,904] Trial 1 finished with value: 0.016716856509447098 and parameters: {'lr': 0.0008746665774731694, 'wd': 0.00016920671299095434, 'hidden_dim': 51, 'num_layers': 2}. Best is trial 0 with value: 0.0028028273954987526.
# [I 2024-11-10 16:33:14,044] Trial 2 finished with value: 0.0002657175064086914 and parameters: {'lr': 0.007001847336373218, 'wd': 1.704043566167442e-06, 'hidden_dim': 44, 'num_layers': 3}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:33:16,372] Trial 3 finished with value: 0.14408080279827118 and parameters: {'lr': 1.4750103801260216e-05, 'wd': 2.778642135398584e-06, 'hidden_dim': 45, 'num_layers': 1}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:33:21,951] Trial 4 finished with value: 0.1562475711107254 and parameters: {'lr': 5.425274096003774e-05, 'wd': 8.32122362699133e-05, 'hidden_dim': 59, 'num_layers': 2}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:33:24,541] Trial 5 finished with value: 0.0013860358158126473 and parameters: {'lr': 9.717471797899906e-05, 'wd': 0.0006121950493215334, 'hidden_dim': 21, 'num_layers': 1}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:33:26,628] Trial 6 finished with value: 0.0018145982176065445 and parameters: {'lr': 0.0006237335565400709, 'wd': 4.4044253953038036e-05, 'hidden_dim': 27, 'num_layers': 2}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:33:27,557] Trial 7 finished with value: 0.0016297224210575223 and parameters: {'lr': 0.008505545313899512, 'wd': 1.71415834343906e-05, 'hidden_dim': 49, 'num_layers': 3}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:33:31,050] Trial 8 finished with value: 0.012757528573274612 and parameters: {'lr': 5.715844675403607e-05, 'wd': 2.2201464365043073e-06, 'hidden_dim': 26, 'num_layers': 3}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:33:34,621] Trial 9 finished with value: 0.1334894597530365 and parameters: {'lr': 3.8587566924093745e-05, 'wd': 0.00011176867600764063, 'hidden_dim': 29, 'num_layers': 3}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:33
. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:02,417] Trial 27 finished with value: 0.0030102944001555443 and parameters: {'lr': 0.0004047397924339405, 'wd': 0.0009399444485381506, 'hidden_dim': 49, 'num_layers': 3}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:03,041] Trial 28 finished with value: 0.0010487096151337028 and parameters: {'lr': 0.0017025469198465415, 'wd': 5.808991368339891e-06, 'hidden_dim': 23, 'num_layers': 2}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:04,135] Trial 29 finished with value: 0.0002738241746556014 and parameters: {'lr': 0.00011674995078538929, 'wd': 2.8873128898662986e-06, 'hidden_dim': 33, 'num_layers': 3}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:07,186] Trial 30 finished with value: 0.002807512180879712 and parameters: {'lr': 0.00010032833890099255, 'wd': 4.152310714317342e-05, 'hidden_dim': 15, 'num_layers': 3}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:08,691] Trial 31 finished with value: 0.0011180263245478272 and parameters: {'lr': 0.00013904265874089706, 'wd': 2.1025339801670393e-06, 'hidden_dim': 34, 'num_layers': 3}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:10,626] Trial 32 finished with value: 0.004546495620161295 and parameters: {'lr': 0.0002198574215749966, 'wd': 1.0736693246250837e-06, 'hidden_dim': 46, 'num_layers': 3}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:11,029] Trial 33 finished with value: 0.0012656713370233774 and parameters: {'lr': 0.00042863783882651665, 'wd': 2.8542012401097386e-06, 'hidden_dim': 38, 'num_layers': 1}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:11,558] Trial 34 finished with value: 0.0015205038944259286 and parameters: {'lr': 0.0009365245946754157, 'wd': 3.0028891177876613e-06, 'hidden_dim': 25, 'num_layers': 2}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:15,604] Trial 35 finished with value: 0.013282334432005882 and parameters: {'lr': 2.9748553890992788e-05, 'wd': 1.6016029339363587e-06, 'hidden_dim': 32, 'num_layers': 4}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:17,756] Trial 36 finished with value: 0.07198479771614075 and parameters: {'lr': 1.423356629420202e-05, 'wd': 0.0003944545463247021, 'hidden_dim': 43, 'num_layers': 2}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:20,475] Trial 37 finished with value: 0.004459763877093792 and parameters: {'lr': 9.729904996245926e-05, 'wd': 5.153071997126661e-06, 'hidden_dim': 54, 'num_layers': 3}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:23,421] Trial 38 finished with value: 0.023323137313127518 and parameters: {'lr': 6.028794467369132e-05, 'wd': 2.0943811966697373e-06, 'hidden_dim': 47, 'num_layers': 2}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:23,936] Trial 39 finished with value: 0.0003217617340851575 and parameters: {'lr': 0.005778424838805271, 'wd': 8.038876078902542e-06, 'hidden_dim': 29, 'num_layers': 1}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:24,086] Trial 40 finished with value: 0.04746202379465103 and parameters: {'lr': 1.0174928131814381e-05, 'wd': 7.662763107494816e-06, 'hidden_dim': 29, 'num_layers': 1}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:24,440] Trial 41 finished with value: 0.000493778265081346 and parameters: {'lr': 0.006591600650066423, 'wd': 3.498045748694159e-06, 'hidden_dim': 28, 'num_layers': 1}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:24,841] Trial 42 finished with value: 0.00033712745062075555 and parameters: {'lr': 0.006469717034877726, 'wd': 3.595489508670082e-06, 'hidden_dim': 28, 'num_layers': 1}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:25,084] Trial 43 finished with value: 0.00027308237622492015 and parameters: {'lr': 0.00411937221641792, 'wd': 1.8859321282694883e-05, 'hidden_dim': 30, 'num_layers': 1}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:25,454] Trial 44 finished with value: 0.000634188880212605 and parameters: {'lr': 0.0037405418251423308, 'wd': 2.0326419328907573e-05, 'hidden_dim': 25, 'num_layers': 1}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:25,683] Trial 45 finished with value: 0.0007414018036797643 and parameters: {'lr': 0.007504939573967851, 'wd': 1.174383916121467e-05, 'hidden_dim': 22, 'num_layers': 1}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:26,193] Trial 46 finished with value: 0.00032633182127028704 and parameters: {'lr': 0.004118866222348271, 'wd': 5.748330157839384e-05, 'hidden_dim': 27, 'num_layers': 1}. Best is trial 2 with value: 0.0002657175064086914.
# [I 2024-11-10 16:34:26,577] Trial 47 finished with value: 0.00017758847388904542 and parameters: {'lr': 0.004242931752889983, 'wd': 9.418111311321393e-05, 'hidden_dim': 18, 'num_layers': 1}. Best is trial 47 with value: 0.00017758847388904542.
# [I 2024-11-10 16:34:26,920] Trial 48 finished with value: 0.0003664226096589118 and parameters: {'lr': 0.0021418633738443243, 'wd': 0.00020112143834721444, 'hidden_dim': 15, 'num_layers': 1}. Best is trial 47 with value: 0.00017758847388904542.
# [I 2024-11-10 16:34:27,288] Trial 49 finished with value: 0.00042208909871988 and parameters: {'lr': 0.0038061431856147806, 'wd': 7.218136943334692e-05, 'hidden_dim': 39, 'num_layers': 1}. Best is trial 47 with value: 0.00017758847388904542.
# Best hyperparameters: {'lr': 0.004242931752889983, 'wd': 9.418111311321393e-05, 'hidden_dim': 18, 'num_layers': 1}

# %% [markdown]
# # Reliance Industries Stock

# %%
import optuna
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch
import torch.nn as nn
import torch.nn.functional as F
from mamba import Mamba, MambaConfig

# Check for CUDA availability
use_cuda = torch.cuda.is_available()
epochs = 100

# Data loading and preprocessing
# Load data
data = pd.read_csv('/content/sample_data/RELIANCE.NS_Reliance_Industries_Limited.csv')
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

# Calculate the percentage change in the 'Close' price
data['pct_chg'] = data['Close'].pct_change() * 100

# Drop the first row if needed and reset the index
data = data.iloc[1:].reset_index(drop=True)

# Extract 'Close' and rate of change
close = data.pop('Close').values
ratechg = data['pct_chg'].apply(lambda x: 0.01 * x).values
data.drop(columns=['pct_chg'], inplace=True)
dat = data.iloc[:, 1:].values

# Columns to normalize
cols_to_normalize = ["Open", "High", "Low", "Adj Close", "Volume"]

# Split data into train, validation, and test
n_test = 100  # The full test set remains constant
n_val = 200
train_data = dat[:-(n_test + n_val)]
val_data = dat[-(n_test + n_val):-n_test]
test_data = dat[-n_test:]

# Calculate mean and std using training and validation sets
mean = np.mean(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)
std = np.std(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)

# Normalize train, validation, and test sets
train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std

# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-3:]  # Using the last 3 data points in test for prediction
testy = ratechg[-n_test:][-3:]  # Last 3 rate changes for evaluation

# Define evaluation metric
def evaluation_metric(y_test, y_hat):
    MSE = mean_squared_error(y_test, y_hat)
    RMSE = MSE**0.5
    MAE = mean_absolute_error(y_test, y_hat)
    R2 = r2_score(y_test, y_hat)
    print('%.6f %.6f %.6f %.6f' % (MSE, RMSE, MAE, R2))

# Define model
class Net(nn.Module):
    def __init__(self, in_dim, out_dim, hidden_dim, num_layers):
        super().__init__()
        self.config = MambaConfig(d_model=hidden_dim, n_layers=num_layers)
        self.mamba = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            Mamba(self.config),
            nn.Linear(hidden_dim, out_dim),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.mamba(x)
        return x.flatten()

# Define objective function for Optuna
def objective(trial):
    # Suggest hyperparameters
    lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
    wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
    hidden_dim = trial.suggest_int('hidden_dim', 8, 64)
    num_layers = trial.suggest_int('num_layers', 1, 4)

    # Set up model and optimizer with trial parameters
    clf = Net(len(trainX[0]), 1, hidden_dim, num_layers)
    opt = torch.optim.Adam(clf.parameters(), lr=lr, weight_decay=wd)

    # Move model to GPU if available
    if use_cuda:
        clf = clf.cuda()

    xt = torch.from_numpy(trainX).float().unsqueeze(0)
    xv = torch.from_numpy(valX).float().unsqueeze(0)
    yt = torch.from_numpy(trainy).float()
    yv = torch.from_numpy(valy).float()

    if use_cuda:
        xt, xv, yt, yv = xt.cuda(), xv.cuda(), yt.cuda(), yv.cuda()

    # Training loop with early stopping
    best_val_loss = float("inf")
    patience, wait = 10, 0
    for e in range(epochs):
        clf.train()
        opt.zero_grad()
        z = clf(xt)
        train_loss = F.mse_loss(z, yt)
        train_loss.backward()
        opt.step()

        # Validation
        clf.eval()
        with torch.no_grad():
            val_pred = clf(xv)
            val_loss = F.mse_loss(val_pred, yv)

        # Early stopping
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    return best_val_loss

# Perform hyperparameter optimization
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

# Print best hyperparameters
print("Best hyperparameters:", study.best_params)

# Retrieve best hyperparameters
best_params = study.best_params
best_lr = best_params['lr']
best_wd = best_params['wd']
best_hidden_dim = best_params['hidden_dim']
best_num_layers = best_params['num_layers']
# Out:
# [I 2024-11-10 16:34:27,332] A new study created in memory with name: no-name-61127ad1-73b6-4c5f-acd4-c05831eb4701
# <ipython-input-35-b6e155c612ed>:84: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
# <ipython-input-35-b6e155c612ed>:85: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
# [I 2024-11-10 16:34:32,199] Trial 0 finished with value: 0.2639835774898529 and parameters: {'lr': 4.049805441427899e-05, 'wd': 4.877223503734596e-05, 'hidden_dim': 63, 'num_layers': 3}. Best is trial 0 with value: 0.2639835774898529.
# [I 2024-11-10 16:34:36,404] Trial 1 finished with value: 0.0001970904995687306 and parameters: {'lr': 0.0011578412226535995, 'wd': 2.9872067736964168e-05, 'hidden_dim': 44, 'num_layers': 4}. Best is trial 1 with value: 0.0001970904995687306.
# [I 2024-11-10 16:34:37,889] Trial 2 finished with value: 0.0011837149504572153 and parameters: {'lr': 0.0006783331720693029, 'wd': 1.516648717949992e-05, 'hidden_dim': 41, 'num_layers': 3}. Best is trial 1 with value: 0.0001970904995687306.
# [I 2024-11-10 16:34:40,887] Trial 3 finished with value: 0.00030986510682851076 and parameters: {'lr': 0.006204324185808169, 'wd': 3.4208489063488485e-06, 'hidden_dim': 19, 'num_layers': 4}. Best is trial 1 with value: 0.0001970904995687306.
# [I 2024-11-10 16:34:42,406] Trial 4 finished with value: 0.0011917257215827703 and parameters: {'lr': 0.00032294524429028504, 'wd': 6.861943001756784e-06, 'hidden_dim': 47, 'num_layers': 2}. Best is trial 1 with value: 0.0001970904995687306.
# [I 2024-11-10 16:34:43,251] Trial 5 finished with value: 0.0004345269117038697 and parameters: {'lr': 0.0003965356860912386, 'wd': 1.1250312980095656e-06, 'hidden_dim': 48, 'num_layers': 1}. Best is trial 1 with value: 0.0001970904995687306.
# [I 2024-11-10 16:34:45,565] Trial 6 finished with value: 0.006825161632150412 and parameters: {'lr': 5.2553104947385515e-05, 'wd': 0.0004718864672779339, 'hidden_dim': 60, 'num_layers': 2}. Best is trial 1 with value: 0.0001970904995687306.
# [I 2024-11-10 16:34:47,625] Trial 7 finished with value: 9.460598084842786e-05 and parameters: {'lr': 0.0017353734689015063, 'wd': 6.917474982141434e-06, 'hidden_dim': 54, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:34:49,593] Trial 8 finished with value: 0.0030661607161164284 and parameters: {'lr': 0.00039403305534716334, 'wd': 0.00012654307363264687, 'hidden_dim': 62, 'num_layers': 4}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:34:50,133] Trial 9 finished with value: 0.0010068975389003754 and parameters: {'lr': 0.0005168461741078756, 'wd': 1.4002536443340384e-06, 'hidden_dim': 51, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:34:50,536] Trial 10 finished with value: 0.0003114685241598636 and parameters: {'lr': 0.008689453989422901, 'wd': 0.000145743172943346, 'hidden_dim': 24, 'num_layers': 1}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:34:51,111] Trial 11 finished with value: 0.001101672649383545 and parameters: {'lr': 0.001957156489399767, 'wd': 1.9941696604891806e-05, 'hidden_dim': 31, 'num_layers': 3}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:34:52,824] Trial 12 finished with value: 0.0002656574943102896 and parameters: {'lr': 0.0015986411412866194, 'wd': 6.486876816329473e-06, 'hidden_dim': 8, 'num_layers': 4}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:34:54,975] Trial 13 finished with value: 0.00898396223783493 and parameters: {'lr': 0.00010819725223090947, 'wd': 5.5108008464133774e-05, 'hidden_dim': 37, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:34:56,077] Trial 14 finished with value: 0.00021344743436202407 and parameters: {'lr': 0.0022300665547849477, 'wd': 1.2927035123735848e-05, 'hidden_dim': 54, 'num_layers': 3}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:34:57,299] Trial 15 finished with value: 0.0005495314253494143 and parameters: {'lr': 1.4815628551053953e-05, 'wd': 3.163578596668253e-06, 'hidden_dim': 40, 'num_layers': 1}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:34:58,698] Trial 16 finished with value: 0.0003994971339125186 and parameters: {'lr': 0.004584972919394102, 'wd': 0.0006123805617800215, 'hidden_dim': 56, 'num_layers': 4}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:34:59,777] Trial 17 finished with value: 0.0006670084549114108 and parameters: {'lr': 0.0010759978122356012, 'wd': 3.3527826349502564e-05, 'hidden_dim': 45, 'num_layers': 3}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35
 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:12,832] Trial 36 finished with value: 0.00017300096806138754 and parameters: {'lr': 0.005668901621998052, 'wd': 0.00013331680496425662, 'hidden_dim': 42, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:13,289] Trial 37 finished with value: 0.00021711377485189587 and parameters: {'lr': 0.006088372960301017, 'wd': 0.00014295416462030736, 'hidden_dim': 41, 'num_layers': 1}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:14,401] Trial 38 finished with value: 0.00026506761787459254 and parameters: {'lr': 0.0029652543611061073, 'wd': 4.3980141409817296e-05, 'hidden_dim': 49, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:15,146] Trial 39 finished with value: 0.00020442726963665336 and parameters: {'lr': 0.0006219607870106033, 'wd': 8.867469368007727e-05, 'hidden_dim': 43, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:15,569] Trial 40 finished with value: 0.0004888441762886941 and parameters: {'lr': 0.0017466667051875648, 'wd': 0.0003775112368762596, 'hidden_dim': 47, 'num_layers': 1}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:15,887] Trial 41 finished with value: 0.00028342680889181793 and parameters: {'lr': 0.005565821777613019, 'wd': 0.00011176703774272941, 'hidden_dim': 39, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:16,843] Trial 42 finished with value: 0.0002601318992674351 and parameters: {'lr': 0.00455417878271783, 'wd': 0.00018043769023007197, 'hidden_dim': 34, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:17,336] Trial 43 finished with value: 0.0005503255524672568 and parameters: {'lr': 0.00716505955861375, 'wd': 5.9318115208938056e-05, 'hidden_dim': 43, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:17,641] Trial 44 finished with value: 0.00022416030697058886 and parameters: {'lr': 0.003279671332914079, 'wd': 0.00014394336504042335, 'hidden_dim': 28, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:19,254] Trial 45 finished with value: 0.03078504279255867 and parameters: {'lr': 0.00022386262325398794, 'wd': 1.6022607394826742e-06, 'hidden_dim': 46, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:19,433] Trial 46 finished with value: 0.0013151728780940175 and parameters: {'lr': 0.0024677869846546317, 'wd': 1.770426470455497e-05, 'hidden_dim': 36, 'num_layers': 1}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:20,790] Trial 47 finished with value: 0.0003540164907462895 and parameters: {'lr': 0.004402627839418454, 'wd': 3.458479826767499e-05, 'hidden_dim': 42, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:22,163] Trial 48 finished with value: 0.00032174057560041547 and parameters: {'lr': 0.0017599302491479946, 'wd': 9.254075055788409e-05, 'hidden_dim': 51, 'num_layers': 3}. Best is trial 7 with value: 9.460598084842786e-05.
# [I 2024-11-10 16:35:24,265] Trial 49 finished with value: 0.08992849290370941 and parameters: {'lr': 4.334385794874078e-05, 'wd': 5.2463792934404174e-05, 'hidden_dim': 21, 'num_layers': 2}. Best is trial 7 with value: 9.460598084842786e-05.
# Best hyperparameters: {'lr': 0.0017353734689015063, 'wd': 6.917474982141434e-06, 'hidden_dim': 54, 'num_layers': 2}

# %% [markdown]
# # NSRGY Stock

# %%
import optuna
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch
import torch.nn as nn
import torch.nn.functional as F
from mamba import Mamba, MambaConfig

# Check for CUDA availability
use_cuda = torch.cuda.is_available()
epochs = 100

# Data loading and preprocessing
# Load data
data = pd.read_csv('/content/sample_data/NSRGY_Nestlé_S.A..csv')
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

# Calculate the percentage change in the 'Close' price
data['pct_chg'] = data['Close'].pct_change() * 100

# Drop the first row if needed and reset the index
data = data.iloc[1:].reset_index(drop=True)

# Extract 'Close' and rate of change
close = data.pop('Close').values
ratechg = data['pct_chg'].apply(lambda x: 0.01 * x).values
data.drop(columns=['pct_chg'], inplace=True)
dat = data.iloc[:, 1:].values

# Columns to normalize
cols_to_normalize = ["Open", "High", "Low", "Adj Close", "Volume"]

# Split data into train, validation, and test
n_test = 100  # The full test set remains constant
n_val = 200
train_data = dat[:-(n_test + n_val)]
val_data = dat[-(n_test + n_val):-n_test]
test_data = dat[-n_test:]

# Calculate mean and std using training and validation sets
mean = np.mean(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)
std = np.std(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)

# Normalize train, validation, and test sets
train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std

# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-3:]  # Using the last 3 data points in test for prediction
testy = ratechg[-n_test:][-3:]  # Last 3 rate changes for evaluation

# Define evaluation metric
def evaluation_metric(y_test, y_hat):
    MSE = mean_squared_error(y_test, y_hat)
    RMSE = MSE**0.5
    MAE = mean_absolute_error(y_test, y_hat)
    R2 = r2_score(y_test, y_hat)
    print('%.6f %.6f %.6f %.6f' % (MSE, RMSE, MAE, R2))

# Define model
class Net(nn.Module):
    def __init__(self, in_dim, out_dim, hidden_dim, num_layers):
        super().__init__()
        self.config = MambaConfig(d_model=hidden_dim, n_layers=num_layers)
        self.mamba = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            Mamba(self.config),
            nn.Linear(hidden_dim, out_dim),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.mamba(x)
        return x.flatten()

# Define objective function for Optuna
def objective(trial):
    # Suggest hyperparameters
    lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
    wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
    hidden_dim = trial.suggest_int('hidden_dim', 8, 64)
    num_layers = trial.suggest_int('num_layers', 1, 4)

    # Set up model and optimizer with trial parameters
    clf = Net(len(trainX[0]), 1, hidden_dim, num_layers)
    opt = torch.optim.Adam(clf.parameters(), lr=lr, weight_decay=wd)

    # Move model to GPU if available
    if use_cuda:
        clf = clf.cuda()

    xt = torch.from_numpy(trainX).float().unsqueeze(0)
    xv = torch.from_numpy(valX).float().unsqueeze(0)
    yt = torch.from_numpy(trainy).float()
    yv = torch.from_numpy(valy).float()

    if use_cuda:
        xt, xv, yt, yv = xt.cuda(), xv.cuda(), yt.cuda(), yv.cuda()

    # Training loop with early stopping
    best_val_loss = float("inf")
    patience, wait = 10, 0
    for e in range(epochs):
        clf.train()
        opt.zero_grad()
        z = clf(xt)
        train_loss = F.mse_loss(z, yt)
        train_loss.backward()
        opt.step()

        # Validation
        clf.eval()
        with torch.no_grad():
            val_pred = clf(xv)
            val_loss = F.mse_loss(val_pred, yv)

        # Early stopping
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    return best_val_loss

# Perform hyperparameter optimization
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

# Print best hyperparameters
print("Best hyperparameters:", study.best_params)

# Retrieve best hyperparameters
best_params = study.best_params
best_lr = best_params['lr']
best_wd = best_params['wd']
best_hidden_dim = best_params['hidden_dim']
best_num_layers = best_params['num_layers']
# Out:
# [I 2024-11-10 16:35:24,307] A new study created in memory with name: no-name-b9348a2a-2b2d-4bcc-83c1-50cd44119144
# <ipython-input-36-dbf930db65f9>:84: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
# <ipython-input-36-dbf930db65f9>:85: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
# [I 2024-11-10 16:35:24,761] Trial 0 finished with value: 0.02550608292222023 and parameters: {'lr': 0.0011548456755387116, 'wd': 3.0689832420717197e-06, 'hidden_dim': 12, 'num_layers': 3}. Best is trial 0 with value: 0.02550608292222023.
# [I 2024-11-10 16:35:25,597] Trial 1 finished with value: 0.0010583184193819761 and parameters: {'lr': 0.0002684944090774832, 'wd': 8.719789133358913e-05, 'hidden_dim': 50, 'num_layers': 3}. Best is trial 1 with value: 0.0010583184193819761.
# [I 2024-11-10 16:35:26,263] Trial 2 finished with value: 0.0031845178455114365 and parameters: {'lr': 0.0016706029167794256, 'wd': 2.526585787519611e-05, 'hidden_dim': 24, 'num_layers': 3}. Best is trial 1 with value: 0.0010583184193819761.
# [I 2024-11-10 16:35:30,760] Trial 3 finished with value: 0.008153696544468403 and parameters: {'lr': 3.3196347740643964e-05, 'wd': 8.436449430044876e-05, 'hidden_dim': 33, 'num_layers': 4}. Best is trial 1 with value: 0.0010583184193819761.
# [I 2024-11-10 16:35:31,932] Trial 4 finished with value: 0.30994096398353577 and parameters: {'lr': 4.008998912263454e-05, 'wd': 0.0003097650474374466, 'hidden_dim': 13, 'num_layers': 1}. Best is trial 1 with value: 0.0010583184193819761.
# [I 2024-11-10 16:35:32,404] Trial 5 finished with value: 0.0004757361311931163 and parameters: {'lr': 0.0014708929865317392, 'wd': 8.93340628297241e-06, 'hidden_dim': 39, 'num_layers': 2}. Best is trial 5 with value: 0.0004757361311931163.
# [I 2024-11-10 16:35:34,511] Trial 6 finished with value: 0.00613532355055213 and parameters: {'lr': 0.00033862312069857426, 'wd': 1.3272072460746719e-05, 'hidden_dim': 20, 'num_layers': 2}. Best is trial 5 with value: 0.0004757361311931163.
# [I 2024-11-10 16:35:35,081] Trial 7 finished with value: 0.0011199540458619595 and parameters: {'lr': 0.0005933253309488004, 'wd': 0.00030248392369723115, 'hidden_dim': 40, 'num_layers': 2}. Best is trial 5 with value: 0.0004757361311931163.
# [I 2024-11-10 16:35:35,355] Trial 8 finished with value: 0.0012603296199813485 and parameters: {'lr': 0.003245396412100686, 'wd': 0.0005804738807432348, 'hidden_dim': 12, 'num_layers': 1}. Best is trial 5 with value: 0.0004757361311931163.
# [I 2024-11-10 16:35:37,461] Trial 9 finished with value: 0.14397673308849335 and parameters: {'lr': 0.00012775303384827277, 'wd': 0.0001037683772861587, 'hidden_dim': 12, 'num_layers': 2}. Best is trial 5 with value: 0.0004757361311931163.
. Best is trial 12 with value: 0.0001309290819335729.
# [I 2024-11-10 16:36:51,766] Trial 46 finished with value: 0.00099937804043293 and parameters: {'lr': 0.00013080391264629098, 'wd': 4.686476765778129e-05, 'hidden_dim': 54, 'num_layers': 4}. Best is trial 12 with value: 0.0001309290819335729.
# [I 2024-11-10 16:36:55,352] Trial 47 finished with value: 0.00010231150372419506 and parameters: {'lr': 0.007003669931395202, 'wd': 0.0001393959207587204, 'hidden_dim': 62, 'num_layers': 4}. Best is trial 47 with value: 0.00010231150372419506.
# [I 2024-11-10 16:36:58,054] Trial 48 finished with value: 0.00021091416419949383 and parameters: {'lr': 0.00255838680523287, 'wd': 0.0001725884812806356, 'hidden_dim': 58, 'num_layers': 4}. Best is trial 47 with value: 0.00010231150372419506.
# [I 2024-11-10 16:36:59,012] Trial 49 finished with value: 0.00021104104234836996 and parameters: {'lr': 0.003918143407481966, 'wd': 0.0007718273590034797, 'hidden_dim': 64, 'num_layers': 2}. Best is trial 47 with value: 0.00010231150372419506.
# Best hyperparameters: {'lr': 0.007003669931395202, 'wd': 0.0001393959207587204, 'hidden_dim': 62, 'num_layers': 4}

# %% [markdown]
# # Petrobas Stock

# %%
import optuna
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch
import torch.nn as nn
import torch.nn.functional as F
from mamba import Mamba, MambaConfig

# Check for CUDA availability
use_cuda = torch.cuda.is_available()
epochs = 100

# Data loading and preprocessing
# Load data
data = pd.read_csv('/content/sample_data/PBR_Petrobras.csv')
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

# Calculate the percentage change in the 'Close' price
data['pct_chg'] = data['Close'].pct_change() * 100

# Drop the first row if needed and reset the index
data = data.iloc[1:].reset_index(drop=True)

# Extract 'Close' and rate of change
close = data.pop('Close').values
ratechg = data['pct_chg'].apply(lambda x: 0.01 * x).values
data.drop(columns=['pct_chg'], inplace=True)
dat = data.iloc[:, 1:].values

# Columns to normalize
cols_to_normalize = ["Open", "High", "Low", "Adj Close", "Volume"]

# Split data into train, validation, and test
n_test = 100  # The full test set remains constant
n_val = 200
train_data = dat[:-(n_test + n_val)]
val_data = dat[-(n_test + n_val):-n_test]
test_data = dat[-n_test:]

# Calculate mean and std using training and validation sets
mean = np.mean(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)
std = np.std(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)

# Normalize train, validation, and test sets
train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std

# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-3:]  # Using the last 3 data points in test for prediction
testy = ratechg[-n_test:][-3:]  # Last 3 rate changes for evaluation

# Define evaluation metric
def evaluation_metric(y_test, y_hat):
    MSE = mean_squared_error(y_test, y_hat)
    RMSE = MSE**0.5
    MAE = mean_absolute_error(y_test, y_hat)
    R2 = r2_score(y_test, y_hat)
    print('%.6f %.6f %.6f %.6f' % (MSE, RMSE, MAE, R2))

# Define model
class Net(nn.Module):
    def __init__(self, in_dim, out_dim, hidden_dim, num_layers):
        super().__init__()
        self.config = MambaConfig(d_model=hidden_dim, n_layers=num_layers)
        self.mamba = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            Mamba(self.config),
            nn.Linear(hidden_dim, out_dim),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.mamba(x)
        return x.flatten()

# Define objective function for Optuna
def objective(trial):
    # Suggest hyperparameters
    lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
    wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
    hidden_dim = trial.suggest_int('hidden_dim', 8, 64)
    num_layers = trial.suggest_int('num_layers', 1, 4)

    # Set up model and optimizer with trial parameters
    clf = Net(len(trainX[0]), 1, hidden_dim, num_layers)
    opt = torch.optim.Adam(clf.parameters(), lr=lr, weight_decay=wd)

    # Move model to GPU if available
    if use_cuda:
        clf = clf.cuda()

    xt = torch.from_numpy(trainX).float().unsqueeze(0)
    xv = torch.from_numpy(valX).float().unsqueeze(0)
    yt = torch.from_numpy(trainy).float()
    yv = torch.from_numpy(valy).float()

    if use_cuda:
        xt, xv, yt, yv = xt.cuda(), xv.cuda(), yt.cuda(), yv.cuda()

    # Training loop with early stopping
    best_val_loss = float("inf")
    patience, wait = 10, 0
    for e in range(epochs):
        clf.train()
        opt.zero_grad()
        z = clf(xt)
        train_loss = F.mse_loss(z, yt)
        train_loss.backward()
        opt.step()

        # Validation
        clf.eval()
        with torch.no_grad():
            val_pred = clf(xv)
            val_loss = F.mse_loss(val_pred, yv)

        # Early stopping
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    return best_val_loss

# Perform hyperparameter optimization
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

# Print best hyperparameters
print("Best hyperparameters:", study.best_params)

# Retrieve best hyperparameters
best_params = study.best_params
best_lr = best_params['lr']
best_wd = best_params['wd']
best_hidden_dim = best_params['hidden_dim']
best_num_layers = best_params['num_layers']
# Out:
# [I 2024-11-10 16:36:59,056] A new study created in memory with name: no-name-d5fcd60c-cea4-4435-a273-e5a1c8e4a832
# <ipython-input-37-d22d5cf75ae5>:84: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
# <ipython-input-37-d22d5cf75ae5>:85: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
# [I 2024-11-10 16:36:59,736] Trial 0 finished with value: 0.003276924369856715 and parameters: {'lr': 0.004538214880406722, 'wd': 4.387561213419411e-05, 'hidden_dim': 36, 'num_layers': 3}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:02,847] Trial 1 finished with value: 0.035230446606874466 and parameters: {'lr': 2.1224076693675003e-05, 'wd': 0.0009108168425523938, 'hidden_dim': 28, 'num_layers': 3}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:06,171] Trial 2 finished with value: 0.09157811850309372 and parameters: {'lr': 0.00011934604984932481, 'wd': 0.0005696030247464601, 'hidden_dim': 45, 'num_layers': 3}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:07,505] Trial 3 finished with value: 0.010026819072663784 and parameters: {'lr': 0.0011222473813432897, 'wd': 3.536119310705634e-05, 'hidden_dim': 12, 'num_layers': 2}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:08,389] Trial 4 finished with value: 0.00442564906552434 and parameters: {'lr': 0.007199822670155196, 'wd': 4.825855223123536e-06, 'hidden_dim': 18, 'num_layers': 3}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:08,620] Trial 5 finished with value: 0.004466161597520113 and parameters: {'lr': 0.006569544055321735, 'wd': 3.0480812021166277e-05, 'hidden_dim': 19, 'num_layers': 1}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:08,937] Trial 6 finished with value: 0.0033827191218733788 and parameters: {'lr': 0.0028259304718512186, 'wd': 0.0006121809643535877, 'hidden_dim': 60, 'num_layers': 1}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:09,279] Trial 7 finished with value: 0.046784304082393646 and parameters: {'lr': 2.497400683516965e-05, 'wd': 4.988139050388303e-06, 'hidden_dim': 8, 'num_layers': 3}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:09,905] Trial 8 finished with value: 0.00802783202379942 and parameters: {'lr': 0.00042737942990008914, 'wd': 2.418924647464492e-05, 'hidden_dim': 53, 'num_layers': 3}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:13,880] Trial 9 finished with value: 0.14380039274692535 and parameters: {'lr': 1.3649292668664242e-05, 'wd': 9.467601311019378e-05, 'hidden_dim': 10, 'num_layers': 4}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:18,049] Trial 10 finished with value: 0.015285047702491283 and parameters: {'lr': 0.00013187121313968758, 'wd': 0.00015588081093895702, 'hidden_dim': 37, 'num_layers': 4}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:18,582] Trial 11 finished with value: 0.003822097321972251 and parameters: {'lr': 0.0018345586556287275, 'wd': 0.0002740887666220066, 'hidden_dim': 62, 'num_layers': 1}. Best is trial 0 with value: 0.003276924369856715.
# [I 2024-11-10 16:37:19,098] Trial 12 finished with value: 0.001901360577903688 and parameters: {'lr': 0.0018918039029500575, 'wd': 1.4982819806295875e-06, 'hidden_dim': 37, 'num_layers': 2}. Best is trial 12 with value: 0.001901360577903688.
# [I 2024-11-10 16:37:20,263] Trial 13 finished with value: 0.00653541786596179 and parameters: {'lr': 0.0006782366103969827, 'wd': 1.0416280117680585e-06, 'hidden_dim': 35, 'num_layers': 2}. Best is trial 12 with value: 0.001901360577903688.
# [I 2024-11-10 16:37:20,626] Trial 14 finished with value: 0.002334242919459939 and parameters: {'lr': 0.003068162030571047, 'wd': 8.247514536120997e-06, 'hidden_dim': 43, 'num_layers': 2}. Best is trial 12 with value: 0.001901360577903688.
# [I 2024-11-10 16:37:21,077] Trial 15 finished with value: 0.0012913247337564826 and parameters: {'lr': 0.0014928018437107891, 'wd': 1.4962149275685726e-06, 'hidden_dim': 47, 'num_layers': 2}. Best is trial 15 with value: 0.0012913247337564826.
# [I 2024-11-10 16:37:23,236] Trial 16 finished with value: 0.027136582881212234 and parameters: {'lr': 0.0002060952761549565, 'wd': 1.1125141780981511e-06, 'hidden_dim': 47, 'num_layers': 2}. Best is trial 15 with value: 0.0012913247337564826.
# [I 2024-11-10 16:37:24,351] Trial 17 finished with value: 0.01770094223320484 and parameters: {'lr': 0.0010269207452191596, 'wd': 2.473827864159048e-06, 'hidden_dim': 28, 'num_layers': 2}. Best is trial 15 with value: 0.0012913247337564826.
# [I 2024-11-10 16:37:24,671] Trial 18 finished with value: 0.010041926056146622 and parameters: {'lr': 0.00038474659981316983, 'wd': 1.2392953537248736e-05, 'hidden_dim': 53, 'num_layers': 1}. Best is trial 15 with value: 0.0012913247337564826.
# [I 2024-11-10 16:37:26,815] Trial 19 finished with value: 0.010437432676553726 and parameters: {'lr': 5.427867640283049e-05, 'wd': 2.3080789829807004e-06, 'hidden_dim': 29, 'num_layers': 2}. Best is trial 15 with value: 0.0012913247337564826.
# [I 2024-11-10 16:37:27,552] Trial 20 finished with value: 0.010480855591595173 and parameters: {'lr': 0.0017215560199949052, 'wd': 2.4012288146149935e-06, 'hidden_dim': 52, 'num_layers': 1}. Best is trial 15 with value: 0.0012913247337564826.
# [I 2024-11-10 16:37:27,893] Trial 21 finished with value: 0.009479331783950329 and parameters: {'lr': 0.003101418072919971, 'wd': 8.217336493909032e-06, 'hidden_dim': 44, 'num_layers': 2}. Best is trial 15 with value: 0.0012913247337564826.
# [I 2024-11-10 16:37:28,162] Trial 22 finished with value: 0.018667997792363167 and parameters: {'lr': 0.009506957868825399, 'wd': 4.243790275162961e-06, 'hidden_dim': 39, 'num_layers': 2}. Best is trial 15 with value: 0.0012913247337564826.
# [I 2024-11-10 16:37:28,901] Trial 23 finished with value: 0.00981579627841711 and parameters: {'lr': 0.0007169809275191224, 'wd': 1.247383719500358e-05, 'hidden_dim': 40, 'num_layers': 2}. Best is trial 15 with value: 0.0012913247337564826.
# [I 2024-11-10 16:37:29,459] Trial 24 finished with value: 0.0007913446752354503 and parameters: {'lr': 0.0026290338491044476, 'wd': 1.624313800478834e-06, 'hidden_dim': 49, 'num_layers': 2}. Best is trial 24 with value: 0.0007913446752354503.
# [I 2024-11-10 16:37:30,674] Trial 25 finished with value: 0.007649132516235113 and parameters: {'lr': 0.0014858317401029522, 'wd': 1.7267106897241908e-06, 'hidden_dim': 50, 'num_layers': 2}. Best is trial 24 with value: 0.0007913446752354503.
# [I 2024-11-10 16:37:31,563] Trial 26 finished with value: 0.012307028286159039 and parameters: {'lr': 0.000732688081418388, 'wd': 1.4049938934783158e-06, 'hidden_dim': 56, 'num_layers': 1}. Best is trial 24 with value: 0.0007913446752354503.
# [I 2024-11-10 16:37:32,782] Trial 27 finished with value: 0.00778674753382802 and parameters: {'lr': 0.004781314649336325, 'wd': 3.101529989237014e-06, 'hidden_dim': 32, 'num_layers': 2}. Best is trial 24 with value: 0.0007913446752354503.
# [I 2024-11-10 16:37:33,974] Trial 28 finished with value: 0.002079287078231573 and parameters: {'lr': 0.002419895715475295, 'wd': 1.6043246058218424e-06, 'hidden_dim': 57, 'num_layers': 3}. Best is trial 24 with value: 0.0007913446752354503.
# [I 2024-11-10 16:37:36,311] Trial 29 finished with value: 0.0010575797641649842 and parameters: {'lr': 0.004185594232886128, 'wd': 6.880042343879476e-05, 'hidden_dim': 48, 'num_layers': 4}. Best is trial 24 with value: 0.0007913446752354503.
# [I 2024-11-10 16:37:39,239] Trial 30 finished with value: 0.0009044923936016858 and parameters: {'lr': 0.003504773051891323, 'wd': 5.7307284205680256e-05, 'hidden_dim': 48, 'num_layers': 4}. Best is trial 24 with value: 0.0007913446752354503.
# [I 2024-11-10 16:37
. Best is trial 24 with value: 0.0007913446752354503.
# [I 2024-11-10 16:38:04,890] Trial 48 finished with value: 0.004298246931284666 and parameters: {'lr': 0.002160580669974404, 'wd': 8.221544799302432e-05, 'hidden_dim': 58, 'num_layers': 4}. Best is trial 24 with value: 0.0007913446752354503.
# [I 2024-11-10 16:38:10,203] Trial 49 finished with value: 0.04572953283786774 and parameters: {'lr': 6.092231897234416e-05, 'wd': 3.5667450033610274e-05, 'hidden_dim': 60, 'num_layers': 4}. Best is trial 24 with value: 0.0007913446752354503.
# Best hyperparameters: {'lr': 0.0026290338491044476, 'wd': 1.624313800478834e-06, 'hidden_dim': 49, 'num_layers': 2}

# %% [markdown]
# # Sasol Stock

# %%
import optuna
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch
import torch.nn as nn
import torch.nn.functional as F
from mamba import Mamba, MambaConfig

# Check for CUDA availability
use_cuda = torch.cuda.is_available()
epochs = 100

# Data loading and preprocessing
# Load data
data = pd.read_csv('/content/sample_data/sasol_stock_data.csv')
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

# Calculate the percentage change in the 'Close' price
data['pct_chg'] = data['Close'].pct_change() * 100

# Drop the first row if needed and reset the index
data = data.iloc[1:].reset_index(drop=True)

# Extract 'Close' and rate of change
close = data.pop('Close').values
ratechg = data['pct_chg'].apply(lambda x: 0.01 * x).values
data.drop(columns=['pct_chg'], inplace=True)
dat = data.iloc[:, 1:].values

# Columns to normalize
cols_to_normalize = ["Open", "High", "Low", "Adj Close", "Volume"]

# Split data into train, validation, and test
n_test = 100  # The full test set remains constant
n_val = 200
train_data = dat[:-(n_test + n_val)]
val_data = dat[-(n_test + n_val):-n_test]
test_data = dat[-n_test:]

# Calculate mean and std using training and validation sets
mean = np.mean(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)
std = np.std(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)

# Normalize train, validation, and test sets
train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std

# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-3:]  # Using the last 3 data points in test for prediction
testy = ratechg[-n_test:][-3:]  # Last 3 rate changes for evaluation

# Define evaluation metric
def evaluation_metric(y_test, y_hat):
    MSE = mean_squared_error(y_test, y_hat)
    RMSE = MSE**0.5
    MAE = mean_absolute_error(y_test, y_hat)
    R2 = r2_score(y_test, y_hat)
    print('%.6f %.6f %.6f %.6f' % (MSE, RMSE, MAE, R2))

# Define model
class Net(nn.Module):
    def __init__(self, in_dim, out_dim, hidden_dim, num_layers):
        super().__init__()
        self.config = MambaConfig(d_model=hidden_dim, n_layers=num_layers)
        self.mamba = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            Mamba(self.config),
            nn.Linear(hidden_dim, out_dim),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.mamba(x)
        return x.flatten()

# Define objective function for Optuna
def objective(trial):
    # Suggest hyperparameters
    lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
    wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
    hidden_dim = trial.suggest_int('hidden_dim', 8, 64)
    num_layers = trial.suggest_int('num_layers', 1, 4)

    # Set up model and optimizer with trial parameters
    clf = Net(len(trainX[0]), 1, hidden_dim, num_layers)
    opt = torch.optim.Adam(clf.parameters(), lr=lr, weight_decay=wd)

    # Move model to GPU if available
    if use_cuda:
        clf = clf.cuda()

    xt = torch.from_numpy(trainX).float().unsqueeze(0)
    xv = torch.from_numpy(valX).float().unsqueeze(0)
    yt = torch.from_numpy(trainy).float()
    yv = torch.from_numpy(valy).float()

    if use_cuda:
        xt, xv, yt, yv = xt.cuda(), xv.cuda(), yt.cuda(), yv.cuda()

    # Training loop with early stopping
    best_val_loss = float("inf")
    patience, wait = 10, 0
    for e in range(epochs):
        clf.train()
        opt.zero_grad()
        z = clf(xt)
        train_loss = F.mse_loss(z, yt)
        train_loss.backward()
        opt.step()

        # Validation
        clf.eval()
        with torch.no_grad():
            val_pred = clf(xv)
            val_loss = F.mse_loss(val_pred, yv)

        # Early stopping
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    return best_val_loss

# Perform hyperparameter optimization
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

# Print best hyperparameters
print("Best hyperparameters:", study.best_params)

# Retrieve best hyperparameters
best_params = study.best_params
best_lr = best_params['lr']
best_wd = best_params['wd']
best_hidden_dim = best_params['hidden_dim']
best_num_layers = best_params['num_layers']
# Out:
# [I 2024-11-10 16:38:10,262] A new study created in memory with name: no-name-4518bb95-ade5-4185-97c5-170a02e68414
# <ipython-input-38-24f162f3be72>:84: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
# <ipython-input-38-24f162f3be72>:85: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
# [I 2024-11-10 16:38:11,712] Trial 0 finished with value: 0.001225325046107173 and parameters: {'lr': 0.008727629959834534, 'wd': 7.631805031535136e-05, 'hidden_dim': 24, 'num_layers': 4}. Best is trial 0 with value: 0.001225325046107173.
# [I 2024-11-10 16:38:15,690] Trial 1 finished with value: 0.3857773244380951 and parameters: {'lr': 3.981210291627973e-05, 'wd': 7.3727117025545135e-06, 'hidden_dim': 18, 'num_layers': 4}. Best is trial 0 with value: 0.001225325046107173.
# [I 2024-11-10 16:38:17,298] Trial 2 finished with value: 0.0012666514376178384 and parameters: {'lr': 0.00600339897668853, 'wd': 0.00021810957243484578, 'hidden_dim': 44, 'num_layers': 4}. Best is trial 0 with value: 0.001225325046107173.
# [I 2024-11-10 16:38:17,629] Trial 3 finished with value: 0.0009565777145326138 and parameters: {'lr': 0.0014192162640268035, 'wd': 0.0009652476401157057, 'hidden_dim': 48, 'num_layers': 1}. Best is trial 3 with value: 0.0009565777145326138.
# [I 2024-11-10 16:38:18,117] Trial 4 finished with value: 0.0012161008780822158 and parameters: {'lr': 0.0004904097585953773, 'wd': 2.0724772145590627e-05, 'hidden_dim': 19, 'num_layers': 3}. Best is trial 3 with value: 0.0009565777145326138.
# [I 2024-11-10 16:38:19,494] Trial 5 finished with value: 0.005219140090048313 and parameters: {'lr': 0.00041709674090049964, 'wd': 2.5513437158153723e-05, 'hidden_dim': 53, 'num_layers': 4}. Best is trial 3 with value: 0.0009565777145326138.
. Best is trial 19 with value: 0.0004439579206518829.
# [I 2024-11-10 16:39:04,111] Trial 37 finished with value: 0.004647284746170044 and parameters: {'lr': 1.3255070463986963e-05, 'wd': 1.4350480585612731e-05, 'hidden_dim': 21, 'num_layers': 3}. Best is trial 19 with value: 0.0004439579206518829.
# [I 2024-11-10 16:39:04,683] Trial 38 finished with value: 0.0008034261991269886 and parameters: {'lr': 0.004252156382612464, 'wd': 0.0002684630642814258, 'hidden_dim': 49, 'num_layers': 2}. Best is trial 19 with value: 0.0004439579206518829.
# [I 2024-11-10 16:39:07,783] Trial 39 finished with value: 0.0008582247537560761 and parameters: {'lr': 0.0017573465706460136, 'wd': 0.00010721928582035862, 'hidden_dim': 32, 'num_layers': 3}. Best is trial 19 with value: 0.0004439579206518829.
# [I 2024-11-10 16:39:10,782] Trial 40 finished with value: 0.017110556364059448 and parameters: {'lr': 0.000252970835230643, 'wd': 4.697045532856883e-05, 'hidden_dim': 15, 'num_layers': 4}. Best is trial 19 with value: 0.0004439579206518829.
# [I 2024-11-10 16:39:11,376] Trial 41 finished with value: 0.0023116054944694042 and parameters: {'lr': 0.00823565570600473, 'wd': 0.0003769406978389817, 'hidden_dim': 41, 'num_layers': 3}. Best is trial 19 with value: 0.0004439579206518829.
# [I 2024-11-10 16:39:14,045] Trial 42 finished with value: 0.0006594330188818276 and parameters: {'lr': 0.006758570525630744, 'wd': 0.00017576851428215213, 'hidden_dim': 33, 'num_layers': 3}. Best is trial 19 with value: 0.0004439579206518829.
# [I 2024-11-10 16:39:15,296] Trial 43 finished with value: 0.0015061992453411222 and parameters: {'lr': 0.002985433048129949, 'wd': 0.0008896729370986934, 'hidden_dim': 23, 'num_layers': 3}. Best is trial 19 with value: 0.0004439579206518829.
# [I 2024-11-10 16:39:18,367] Trial 44 finished with value: 0.07910990715026855 and parameters: {'lr': 6.330597161176392e-05, 'wd': 0.0004925275323387469, 'hidden_dim': 27, 'num_layers': 3}. Best is trial 19 with value: 0.0004439579206518829.
# [I 2024-11-10 16:39:19,469] Trial 45 finished with value: 0.0006154046859592199 and parameters: {'lr': 0.006170019586042578, 'wd': 0.0007181169781449741, 'hidden_dim': 37, 'num_layers': 3}. Best is trial 19 with value: 0.0004439579206518829.
# [I 2024-11-10 16:39:20,617] Trial 46 finished with value: 0.00042250065598636866 and parameters: {'lr': 0.00984800702937031, 'wd': 0.00021927054805574915, 'hidden_dim': 39, 'num_layers': 2}. Best is trial 46 with value: 0.00042250065598636866.
# [I 2024-11-10 16:39:21,398] Trial 47 finished with value: 0.0007597918738611042 and parameters: {'lr': 0.003148371046421402, 'wd': 0.00022785387624002292, 'hidden_dim': 44, 'num_layers': 2}. Best is trial 46 with value: 0.00042250065598636866.
# [I 2024-11-10 16:39:22,354] Trial 48 finished with value: 0.0028077815659344196 and parameters: {'lr': 0.0004603418694957197, 'wd': 8.593017835418571e-05, 'hidden_dim': 39, 'num_layers': 2}. Best is trial 46 with value: 0.00042250065598636866.
# [I 2024-11-10 16:39:24,897] Trial 49 finished with value: 0.34786495566368103 and parameters: {'lr': 2.223616363366228e-05, 'wd': 1.6897184597807215e-05, 'hidden_dim': 49, 'num_layers': 2}. Best is trial 46 with value: 0.00042250065598636866.
# Best hyperparameters: {'lr': 0.00984800702937031, 'wd': 0.00021927054805574915, 'hidden_dim': 39, 'num_layers': 2}

# %% [markdown]
# # MTN Stock Data

# %%
df = pd.read_csv('/content/sample_data/MTN_stock_data.csv')
df.head()
# Out:
#                         Date       Open       High        Low      Close  \
# 0  2014-01-02 00:00:00+00:00  75.169998  75.419998  74.070000  74.989998
# 1  2014-01-03 00:00:00+00:00  74.980003  75.309998  74.260002  74.769997
# 2  2014-01-06 00:00:00+00:00  75.010002  75.040001  74.089996  74.169998
# 3  2014-01-07 00:00:00+00:00  74.440002  75.089996  73.519997  73.940002
# 4  2014-01-08 00:00:00+00:00  73.879997  73.879997  72.129997  72.570000
#
#    Adj Close  Volume
# 0  57.500946  210000
# 1  57.332237  105600
# 2  56.872173  119900
# 3  56.695801  107100
# 4  55.645329  181800

# %%
import optuna
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch
import torch.nn as nn
import torch.nn.functional as F
from mamba import Mamba, MambaConfig

# Check for CUDA availability
use_cuda = torch.cuda.is_available()
epochs = 100

# Data loading and preprocessing
# Load data
data = pd.read_csv('/content/sample_data/MTN_stock_data.csv')
data['Date'] = pd.to_datetime(data['Date'],  format='%Y-%m-%d %H:%M:%S%z', errors='coerce')

# Calculate the percentage change in the 'Close' price
data['pct_chg'] = data['Close'].pct_change() * 100

# Drop the first row if needed and reset the index
data = data.iloc[1:].reset_index(drop=True)

# Extract 'Close' and rate of change
close = data.pop('Close').values
ratechg = data['pct_chg'].apply(lambda x: 0.01 * x).values
data.drop(columns=['pct_chg'], inplace=True)
dat = data.iloc[:, 1:].values

# Columns to normalize
cols_to_normalize = ["Open", "High", "Low", "Adj Close", "Volume"]

# Split data into train, validation, and test
n_test = 100  # The full test set remains constant
n_val = 200
train_data = dat[:-(n_test + n_val)]
val_data = dat[-(n_test + n_val):-n_test]
test_data = dat[-n_test:]

# Calculate mean and std using training and validation sets
mean = np.mean(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)
std = np.std(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)

# Normalize train, validation, and test sets
train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std

# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-3:]  # Using the last 3 data points in test for prediction
testy = ratechg[-n_test:][-3:]  # Last 3 rate changes for evaluation

# Define evaluation metric
def evaluation_metric(y_test, y_hat):
    MSE = mean_squared_error(y_test, y_hat)
    RMSE = MSE**0.5
    MAE = mean_absolute_error(y_test, y_hat)
    R2 = r2_score(y_test, y_hat)
    print('%.6f %.6f %.6f %.6f' % (MSE, RMSE, MAE, R2))

# Define model
class Net(nn.Module):
    def __init__(self, in_dim, out_dim, hidden_dim, num_layers):
        super().__init__()
        self.config = MambaConfig(d_model=hidden_dim, n_layers=num_layers)
        self.mamba = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            Mamba(self.config),
            nn.Linear(hidden_dim, out_dim),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.mamba(x)
        return x.flatten()

# Define objective function for Optuna
def objective(trial):
    # Suggest hyperparameters
    lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
    wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
    hidden_dim = trial.suggest_int('hidden_dim', 8, 64)
    num_layers = trial.suggest_int('num_layers', 1, 4)

    # Set up model and optimizer with trial parameters
    clf = Net(len(trainX[0]), 1, hidden_dim, num_layers)
    opt = torch.optim.Adam(clf.parameters(), lr=lr, weight_decay=wd)

    # Move model to GPU if available
    if use_cuda:
        clf = clf.cuda()

    xt = torch.from_numpy(trainX).float().unsqueeze(0)
    xv = torch.from_numpy(valX).float().unsqueeze(0)
    yt = torch.from_numpy(trainy).float()
    yv = torch.from_numpy(valy).float()

    if use_cuda:
        xt, xv, yt, yv = xt.cuda(), xv.cuda(), yt.cuda(), yv.cuda()

    # Training loop with early stopping
    best_val_loss = float("inf")
    patience, wait = 10, 0
    for e in range(epochs):
        clf.train()
        opt.zero_grad()
        z = clf(xt)
        train_loss = F.mse_loss(z, yt)
        train_loss.backward()
        opt.step()

        # Validation
        clf.eval()
        with torch.no_grad():
            val_pred = clf(xv)
            val_loss = F.mse_loss(val_pred, yv)

        # Early stopping
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    return best_val_loss

# Perform hyperparameter optimization
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

# Print best hyperparameters
print("Best hyperparameters:", study.best_params)

# Retrieve best hyperparameters
best_params = study.best_params
best_lr = best_params['lr']
best_wd = best_params['wd']
best_hidden_dim = best_params['hidden_dim']
best_num_layers = best_params['num_layers']
# Out:
# [I 2024-11-10 16:42:10,789] A new study created in memory with name: no-name-7254ba55-c1ae-4b7d-9dfe-20cd57b40bd6
# <ipython-input-41-9ba9f160fd70>:84: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-2)
# <ipython-input-41-9ba9f160fd70>:85: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   wd = trial.suggest_loguniform('wd', 1e-6, 1e-3)
# [I 2024-11-10 16:42:15,744] Trial 0 finished with value: 0.1878051459789276 and parameters: {'lr': 2.646210770228286e-05, 'wd': 1.7123416354785758e-06, 'hidden_dim': 30, 'num_layers': 3}. Best is trial 0 with value: 0.1878051459789276.
# [I 2024-11-10 16:42:21,311] Trial 1 finished with value: 0.03195078670978546 and parameters: {'lr': 1.2877168462231178e-05, 'wd': 0.0005264613420627403, 'hidden_dim': 47, 'num_layers': 4}. Best is trial 1 with value: 0.03195078670978546.
# [I 2024-11-10 16:42:23,432] Trial 2 finished with value: 0.0003097000590059906 and parameters: {'lr': 0.004205533606291724, 'wd': 1.8748145925650504e-05, 'hidden_dim': 46, 'num_layers': 2}. Best is trial 2 with value: 0.0003097000590059906.
# [I 2024-11-10 16:42:24,784] Trial 3 finished with value: 0.000263049325440079 and parameters: {'lr': 0.009442416729577801, 'wd': 0.00013320238586808108, 'hidden_dim': 15, 'num_layers': 3}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:26,356] Trial 4 finished with value: 0.000624633627012372 and parameters: {'lr': 0.0038940824467484226, 'wd': 0.0006483206457827982, 'hidden_dim': 62, 'num_layers': 4}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:28,186] Trial 5 finished with value: 0.0006751966429874301 and parameters: {'lr': 0.004606495111039816, 'wd': 0.0005863549789672717, 'hidden_dim': 45, 'num_layers': 2}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:29,100] Trial 6 finished with value: 0.0004151625034864992 and parameters: {'lr': 0.004473167149838119, 'wd': 4.124057939501612e-05, 'hidden_dim': 43, 'num_layers': 2}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:29,386] Trial 7 finished with value: 0.00403534946963191 and parameters: {'lr': 0.001070718090188676, 'wd': 8.574560419012132e-06, 'hidden_dim': 24, 'num_layers': 1}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:32,156] Trial 8 finished with value: 0.351047158241272 and parameters: {'lr': 1.1430105958317555e-05, 'wd': 1.1664715237925508e-05, 'hidden_dim': 34, 'num_layers': 2}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:35,732] Trial 9 finished with value: 0.005441179033368826 and parameters: {'lr': 2.390205622752776e-05, 'wd': 0.0001052829281396806, 'hidden_dim': 54, 'num_layers': 3}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:36,912] Trial 10 finished with value: 0.20775490999221802 and parameters: {'lr': 0.00019880532625197124, 'wd': 0.00011937693264316497, 'hidden_dim': 8, 'num_layers': 1}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:37,757] Trial 11 finished with value: 0.0009182740468531847 and parameters: {'lr': 0.008397410164695938, 'wd': 2.9569614033353515e-05, 'hidden_dim': 14, 'num_layers': 3}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:38,673] Trial 12 finished with value: 0.0033088212367147207 and parameters: {'lr': 0.0010193206979680252, 'wd': 0.00013307019750307422, 'hidden_dim': 23, 'num_layers': 2}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:39,902] Trial 13 finished with value: 0.002510403050109744 and parameters: {'lr': 0.0013016367149923385, 'wd': 3.28601934341595e-06, 'hidden_dim': 55, 'num_layers': 3}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:40,099] Trial 14 finished with value: 0.0012768678134307265 and parameters: {'lr': 0.0002658465453646363, 'wd': 3.4211687988971465e-05, 'hidden_dim': 39, 'num_layers': 1}. Best is trial 3 with value: 0.000263049325440079.
# [I 2024-11-10 16:42:44,643] Trial 15 finished with value: 0.0002257260784972459 and parameters: {'lr': 0.007956492350656492, 'wd': 1.2037844626907559e-05, 'hidden_dim': 18, 'num_layers': 4}. Best is trial 15 with value: 0.0002257260784972459.
# [I 2024-11-10 16:42:48,940] Trial 16 finished with value: 0.02647341601550579 and parameters: {'lr': 0.0001268481441905895, 'wd': 5.228606765188924e-06, 'hidden_dim': 16, 'num_layers': 4}. Best is trial 15 with value: 0.0002257260784972459.
# [I 2024-11-10 16:42:51,032] Trial 17 finished with value: 0.0018342867260798812 and parameters: {'lr': 0.008680903525841319, 'wd': 0.00029891305088015067, 'hidden_dim': 8, 'num_layers': 4}. Best is trial 15 with value: 0.0002257260784972459.
# [I 2024-11-10 16:42:52,310] Trial 18 finished with value: 0.0014131080824881792 and parameters: {'lr': 0.0018694706043805435, 'wd': 7.576384429786109e-05, 'hidden_dim': 21, 'num_layers': 4}. Best is trial 15 with value: 0.0002257260784972459.
# [I 2024-11-10 16:42:55,395] Trial 19 finished with value: 0.01383672934025526 and parameters: {'lr': 0.000503614092579617, 'wd': 5.6101299074689e-05, 'hidden_dim': 15, 'num_layers': 3}. Best is trial 15 with value: 0.0002257260784972459.
# [I 2024-11-10 16:42:59,371] Trial 20 finished with value: 0.0030690208077430725 and parameters: {'lr': 8.460738056110831e-05, 'wd': 1.0225995804383736e-06, 'hidden_dim': 30, 'num_layers': 4}. Best is trial 15 with value: 0.0002257260784972459.
# [I 2024-11-10 16:43:00,053] Trial 21 finished with value: 0.0018272086745128036 and parameters: {'lr': 0.009918538309760014, 'wd': 1.7243145915307676e-05, 'hidden_dim': 52, 'num_layers': 2}. Best is trial 15 with value: 0.0002257260784972459.
# [I 2024-11-10 16:43:01,542] Trial 22 finished with value: 0.00022533832816407084 and parameters: {'lr': 0.0023437069274849192, 'wd': 1.800675720957392e-05, 'hidden_dim': 27, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:02,294] Trial 23 finished with value: 0.004114547744393349 and parameters: {'lr': 0.0020859412335771546, 'wd': 0.00022849152928418044, 'hidden_dim': 27, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:03,376] Trial 24 finished with value: 0.0005385202239267528 and parameters: {'lr': 0.0026510996419237547, 'wd': 4.2127062390395825e-06, 'hidden_dim': 18, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:04,082] Trial 25 finished with value: 0.003606871934607625 and parameters: {'lr': 0.0005505222803107058, 'wd': 8.8117018028251e-06, 'hidden_dim': 12, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:06,161] Trial 26 finished with value: 0.00032239704160019755 and parameters: {'lr': 0.00573348983059833, 'wd': 2.0953349706417826e-05, 'hidden_dim': 20, 'num_layers': 4}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:07,608] Trial 27 finished with value: 0.0006261152448132634 and parameters: {'lr': 0.0025241194186143134, 'wd': 0.00020070499637463932, 'hidden_dim': 27, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:11,921] Trial 28 finished with value: 0.00023507769219577312 and parameters: {'lr': 0.006838061869523465, 'wd': 5.730115585608056e-05, 'hidden_dim': 34, 'num_layers': 4}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:12,612] Trial 29 finished with value: 0.003708680858835578 and parameters: {'lr': 0.000694830444012268, 'wd': 2.361087672564312e-06, 'hidden_dim': 36, 'num_layers': 4}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:14,630] Trial 30 finished with value: 0.0006658837082795799 and parameters: {'lr': 0.00593735355004485, 'wd': 6.659330822919896e-06, 'hidden_dim': 32, 'num_layers': 4}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:16,268] Trial 31 finished with value: 0.0014801350189372897 and parameters: {'lr': 0.006631391190192093, 'wd': 6.636610365874495e-05, 'hidden_dim': 27, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:17,295] Trial 32 finished with value: 0.00099087820854038 and parameters: {'lr': 0.0039074205649965495, 'wd': 1.1621577906909507e-05, 'hidden_dim': 38, 'num_layers': 4}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:21,643] Trial 33 finished with value: 0.0005094752996228635 and parameters: {'lr': 0.00266920209697444, 'wd': 2.4108374778198557e-05, 'hidden_dim': 11, 'num_layers': 4}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:22,888] Trial 34 finished with value: 0.0003454127872828394 and parameters: {'lr': 0.00891400874917926, 'wd': 4.980310477980142e-05, 'hidden_dim': 19, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:23,984] Trial 35 finished with value: 0.002366614295169711 and parameters: {'lr': 0.0030601488352633745, 'wd': 1.7252117850430783e-05, 'hidden_dim': 24, 'num_layers': 4}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:25,267] Trial 36 finished with value: 0.0015535702696070075 and parameters: {'lr': 0.001568089290299276, 'wd': 8.059123977777159e-05, 'hidden_dim': 41, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:26,638] Trial 37 finished with value: 0.0004960215883329511 and parameters: {'lr': 0.005150670804619075, 'wd': 0.00029927119920966465, 'hidden_dim': 30, 'num_layers': 4}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:27,331] Trial 38 finished with value: 0.003499138168990612 and parameters: {'lr': 0.003721092500771911, 'wd': 0.0008018331134980085, 'hidden_dim': 23, 'num_layers': 2}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:28,906] Trial 39 finished with value: 0.0006277143256738782 and parameters: {'lr': 0.006096974457676893, 'wd': 4.010136029261421e-05, 'hidden_dim': 17, 'num_layers': 4}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:32,201] Trial 40 finished with value: 0.0003095379506703466 and parameters: {'lr': 0.003754733483806317, 'wd': 1.3538587769126772e-05, 'hidden_dim': 63, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:32,974] Trial 41 finished with value: 0.0008543279836885631 and parameters: {'lr': 0.003801253158025713, 'wd': 1.2757594065383874e-05, 'hidden_dim': 64, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:34,110] Trial 42 finished with value: 0.0005165936308912933 and parameters: {'lr': 0.006981213924693628, 'wd': 8.312546059307832e-06, 'hidden_dim': 48, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:34,896] Trial 43 finished with value: 0.0006195604219101369 and parameters: {'lr': 0.0046482393889138406, 'wd': 1.4341165184264427e-05, 'hidden_dim': 34, 'num_layers': 2}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:37,321] Trial 44 finished with value: 0.0007246472523547709 and parameters: {'lr': 5.56116273799257e-05, 'wd': 2.450807215631528e-05, 'hidden_dim': 60, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:38,092] Trial 45 finished with value: 0.0021944351028651 and parameters: {'lr': 0.001009997894909544, 'wd': 0.00015192217019628374, 'hidden_dim': 13, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:41,216] Trial 46 finished with value: 0.00023139870609156787 and parameters: {'lr': 0.007127202538685892, 'wd': 2.9785569576230487e-05, 'hidden_dim': 49, 'num_layers': 3}. Best is trial 22 with value: 0.00022533832816407084.
# [I 2024-11-10 16:43:43,252] Trial 47 finished with value: 0.00021546441712416708 and parameters: {'lr': 0.009807515737823923, 'wd': 3.051959676985035e-05, 'hidden_dim': 48, 'num_layers': 2}. Best is trial 47 with value: 0.00021546441712416708.
# [I 2024-11-10 16:43:44,053] Trial 48 finished with value: 0.000470645260065794 and parameters: {'lr': 0.007419843317584431, 'wd': 2.8672163732817915e-05, 'hidden_dim': 47, 'num_layers': 2}. Best is trial 47 with value: 0.00021546441712416708.
# [I 2024-11-10 16:43:44,431] Trial 49 finished with value: 0.002995059359818697 and parameters: {'lr': 0.009145767840781947, 'wd': 3.924251127024814e-05, 'hidden_dim': 51, 'num_layers': 2}. Best is trial 47 with value: 0.00021546441712416708.
# Best hyperparameters: {'lr': 0.009807515737823923, 'wd': 3.051959676985035e-05, 'hidden_dim': 48, 'num_layers': 2}
