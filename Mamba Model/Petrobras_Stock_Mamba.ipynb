# %% [markdown]
# # Petrobras Stock

# %%
import os
os.chdir("/content/sample_data")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch
import torch.nn as nn
import torch.nn.functional as F
from mamba import Mamba, MambaConfig

# %% [markdown]
# # Horizon 3

# %%
# Set default parameters
use_cuda = torch.cuda.is_available()
seed = 1
epochs = 100
lr = 0.0026290338491044476
wd = 1.624313800478834e-06
hidden_dim = 49
num_layers = 2
lookback_window = 96
horizon = 3  # Set horizon as desired

def evaluation_metric(y_test, y_hat):
    MSE = mean_squared_error(y_test, y_hat)
    MAE = mean_absolute_error(y_test, y_hat)
    print('%.6f %.6f' % (MSE, MAE))

def set_seed(seed, cuda):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if cuda:
        torch.cuda.manual_seed(seed)

def dateinf(series, n_test):
    lt = len(series)
    print('Training start', series[0])
    print('Training end', series[lt - n_test - 1])
    print('Testing start', series[lt - n_test])
    print('Testing end', series[lt - 1])

set_seed(seed, use_cuda)

class Net(nn.Module):
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.config = MambaConfig(d_model=hidden_dim, n_layers=num_layers)
        self.mamba = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            Mamba(self.config),
            nn.Linear(hidden_dim, out_dim),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.mamba(x)
        return x.flatten()

def PredictWithData(trainX, trainy, valX, valy, testX):
    clf = Net(len(trainX[0]), 1)
    opt = torch.optim.Adam(clf.parameters(), lr=lr, weight_decay=wd)
    xt = torch.from_numpy(trainX).float().unsqueeze(0)  # Add batch dimension
    xv = torch.from_numpy(valX).float().unsqueeze(0)    # Add batch dimension
    xtest = torch.from_numpy(testX).float().unsqueeze(0)  # Add batch dimension
    yt = torch.from_numpy(trainy).float()
    yv = torch.from_numpy(valy).float()

    # Move data to GPU if available
    if use_cuda:
        clf = clf.cuda()
        xt, xv, xtest, yt, yv = xt.cuda(), xv.cuda(), xtest.cuda(), yt.cuda(), yv.cuda()

    train_losses = []
    val_losses = []

    # Training loop
    for e in range(epochs):
        clf.train()
        z = clf(xt)
        train_loss = F.mse_loss(z, yt)
        train_losses.append(train_loss.item())

        # Validation loss
        clf.eval()
        with torch.no_grad():
            val_pred = clf(xv)
            val_loss = F.mse_loss(val_pred, yv)
            val_losses.append(val_loss.item())

        # Backward pass and optimization
        opt.zero_grad()
        train_loss.backward()
        opt.step()

        # Print progress every 10 epochs
        if e % 10 == 0:
            print(f'Epoch {e} | Train Loss: {train_loss.item():.4f} | Validation Loss: {val_loss.item():.4f}')

    # Test predictions
    with torch.no_grad():
        clf.eval()
        test_pred = clf(xtest)
        if use_cuda:
            test_pred = test_pred.cpu()
        yhat = test_pred.numpy().flatten()

    # Plot training and validation losses
    plt.figure(figsize=(10, 6))
    plt.plot(range(epochs), train_losses, label='Training Loss')
    plt.plot(range(epochs), val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss over Epochs (Petrobras Stock)')
    plt.legend()
    plt.show()

    return yhat

# %%
# Load data
data = pd.read_csv('/content/sample_data/PBR_Petrobras.csv')
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

# Calculate the percentage change in the 'Close' price
data['pct_chg'] = data['Close'].pct_change() * 100

# Drop the first row if needed and reset the index
data = data.iloc[1:].reset_index(drop=True)

# Extract 'Close' and rate of change
close = data.pop('Close').values
ratechg = data['pct_chg'].apply(lambda x: 0.01 * x).values
data.drop(columns=['pct_chg'], inplace=True)
dat = data.iloc[:, 1:].values

# Columns to normalize
cols_to_normalize = ["Open", "High", "Low", "Adj Close", "Volume"]

# Split data into train, validation, and test
n_test = 100  # The full test set remains constant
n_val = 200
train_data = dat[:-(n_test + n_val)]
val_data = dat[-(n_test + n_val):-n_test]
test_data = dat[-n_test:]

# Calculate mean and std using training and validation sets
mean = np.mean(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)
std = np.std(np.vstack((train_data, val_data))[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]], axis=0)

# Normalize train, validation, and test sets
train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (train_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (val_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std
test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] = (test_data[:, [data.columns.get_loc(col) - 1 for col in cols_to_normalize]] - mean) / std

# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-horizon:]  # Use the last 'horizon' data points in test for prediction
testy = ratechg[-n_test:][-horizon:]  # Last 'horizon' rate changes for evaluation

# %%
# Predicting
predictions = PredictWithData(trainX, trainy, valX, valy, testX)
# Out:
# Epoch 0 | Train Loss: 0.5351 | Validation Loss: 0.1809
# Epoch 10 | Train Loss: 0.0268 | Validation Loss: 0.2363
# Epoch 20 | Train Loss: 0.0127 | Validation Loss: 0.0224
# Epoch 30 | Train Loss: 0.0028 | Validation Loss: 0.0432
# Epoch 40 | Train Loss: 0.0021 | Validation Loss: 0.0201
# Epoch 50 | Train Loss: 0.0015 | Validation Loss: 0.0105
# Epoch 60 | Train Loss: 0.0012 | Validation Loss: 0.0160
# Epoch 70 | Train Loss: 0.0011 | Validation Loss: 0.0089
# Epoch 80 | Train Loss: 0.0011 | Validation Loss: 0.0094
# Epoch 90 | Train Loss: 0.0010 | Validation Loss: 0.0103

# %%
# Calculate predicted stock prices for the last 'horizon' steps
time = data['Date'][-n_test:][-horizon:]
data1 = close[-n_test:][-horizon:]
finalpredicted_stock_price = []
pred = close[-n_test - 1]

# Calculate stock prices based on predictions
for i in range(horizon):
    pred = data1[i] * (1 + predictions[i])
    finalpredicted_stock_price.append(pred)

# Convert `data1` (test close prices) to ratechg
data1_pct_chg = np.diff(data1) / data1[:-1] * 100  # Calculate percentage change
test_ratechg = data1_pct_chg * 0.01  # Scale by 0.01 to match ratechg format

# Convert `finalpredicted_stock_price` (predicted close prices) to ratechg
predicted_pct_chg = np.diff(finalpredicted_stock_price) / np.array(finalpredicted_stock_price[:-1]) * 100
predicted_ratechg = predicted_pct_chg * 0.01  # Scale by 0.01

# %%
# Evaluate metrics
print('MSE MAE')
evaluation_metric(test_ratechg[:horizon-1], predicted_ratechg)
# Out:
# MSE MAE
# 0.000803 0.022797

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(time, data1, label='Actual Stock Price')
plt.plot(time, finalpredicted_stock_price, label='Predicted Stock Price')
plt.title('Petrobras Stock Price Prediction')
plt.xlabel('Time', fontsize=12, verticalalignment='top')
plt.ylabel('Close', fontsize=14, horizontalalignment='center')
plt.legend()
plt.show()

# %% [markdown]
# # Horizon 5

# %%
def PredictWithData(trainX, trainy, valX, valy, testX):
    clf = Net(len(trainX[0]), 1)
    opt = torch.optim.Adam(clf.parameters(), lr=lr, weight_decay=wd)
    xt = torch.from_numpy(trainX).float().unsqueeze(0)  # Add batch dimension
    xv = torch.from_numpy(valX).float().unsqueeze(0)    # Add batch dimension
    xtest = torch.from_numpy(testX).float().unsqueeze(0)  # Add batch dimension
    yt = torch.from_numpy(trainy).float()
    yv = torch.from_numpy(valy).float()

    # Move data to GPU if available
    if use_cuda:
        clf = clf.cuda()
        xt, xv, xtest, yt, yv = xt.cuda(), xv.cuda(), xtest.cuda(), yt.cuda(), yv.cuda()

    train_losses = []
    val_losses = []

    # Training loop
    for e in range(epochs):
        clf.train()
        z = clf(xt)
        train_loss = F.mse_loss(z, yt)
        train_losses.append(train_loss.item())

        # Validation loss
        clf.eval()
        with torch.no_grad():
            val_pred = clf(xv)
            val_loss = F.mse_loss(val_pred, yv)
            val_losses.append(val_loss.item())

        # Backward pass and optimization
        opt.zero_grad()
        train_loss.backward()
        opt.step()

        # Print progress every 10 epochs
        if e % 10 == 0:
            print(f'Epoch {e} | Train Loss: {train_loss.item():.4f} | Validation Loss: {val_loss.item():.4f}')

    # Test predictions
    with torch.no_grad():
        clf.eval()
        test_pred = clf(xtest)
        if use_cuda:
            test_pred = test_pred.cpu()
        yhat = test_pred.numpy().flatten()


    return yhat

# %%
horizon = 5

# %%
# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-horizon:]  # Use the last 'horizon' data points in test for prediction
testy = ratechg[-n_test:][-horizon:]  # Last 'horizon' rate changes for evaluation

# %%
# Predicting
predictions = PredictWithData(trainX, trainy, valX, valy, testX)
# Out:
# Epoch 0 | Train Loss: 0.1047 | Validation Loss: 0.0937
# Epoch 10 | Train Loss: 0.0035 | Validation Loss: 0.0033
# Epoch 20 | Train Loss: 0.0024 | Validation Loss: 0.0026
# Epoch 30 | Train Loss: 0.0017 | Validation Loss: 0.0011
# Epoch 40 | Train Loss: 0.0011 | Validation Loss: 0.0009
# Epoch 50 | Train Loss: 0.0011 | Validation Loss: 0.0008
# Epoch 60 | Train Loss: 0.0010 | Validation Loss: 0.0008
# Epoch 70 | Train Loss: 0.0009 | Validation Loss: 0.0007
# Epoch 80 | Train Loss: 0.0009 | Validation Loss: 0.0007
# Epoch 90 | Train Loss: 0.0009 | Validation Loss: 0.0007

# %%
# Calculate predicted stock prices for the last 'horizon' steps
time = data['Date'][-n_test:][-horizon:]
data1 = close[-n_test:][-horizon:]
finalpredicted_stock_price = []
pred = close[-n_test - 1]

# Calculate stock prices based on predictions
for i in range(horizon):
    pred = data1[i] * (1 + predictions[i])
    finalpredicted_stock_price.append(pred)

# Convert `data1` (test close prices) to ratechg
data1_pct_chg = np.diff(data1) / data1[:-1] * 100  # Calculate percentage change
test_ratechg = data1_pct_chg * 0.01  # Scale by 0.01 to match ratechg format

# Convert `finalpredicted_stock_price` (predicted close prices) to ratechg
predicted_pct_chg = np.diff(finalpredicted_stock_price) / np.array(finalpredicted_stock_price[:-1]) * 100
predicted_ratechg = predicted_pct_chg * 0.01  # Scale by 0.01

# %%
# Evaluate metrics
print('MSE MAE')
evaluation_metric(test_ratechg[:horizon-1], predicted_ratechg)
# Out:
# MSE MAE
# 0.000008 0.001893

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(time, data1, label='Actual Stock Price')
plt.plot(time, finalpredicted_stock_price, label='Predicted Stock Price')
plt.title('Nestle Stock Price Prediction')
plt.xlabel('Time', fontsize=12, verticalalignment='top')
plt.ylabel('Close', fontsize=14, horizontalalignment='center')
plt.legend()
plt.show()

# %% [markdown]
# # Horizon 10

# %%
horizon = 10

# %%
# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-horizon:]  # Use the last 'horizon' data points in test for prediction
testy = ratechg[-n_test:][-horizon:]  # Last 'horizon' rate changes for evaluation

# %%
# Predicting
predictions = PredictWithData(trainX, trainy, valX, valy, testX)
# Out:
# Epoch 0 | Train Loss: 0.0946 | Validation Loss: 0.2011
# Epoch 10 | Train Loss: 0.0017 | Validation Loss: 0.0204
# Epoch 20 | Train Loss: 0.0037 | Validation Loss: 0.0112
# Epoch 30 | Train Loss: 0.0012 | Validation Loss: 0.0106
# Epoch 40 | Train Loss: 0.0014 | Validation Loss: 0.0048
# Epoch 50 | Train Loss: 0.0011 | Validation Loss: 0.0048
# Epoch 60 | Train Loss: 0.0011 | Validation Loss: 0.0054
# Epoch 70 | Train Loss: 0.0010 | Validation Loss: 0.0046
# Epoch 80 | Train Loss: 0.0009 | Validation Loss: 0.0043
# Epoch 90 | Train Loss: 0.0009 | Validation Loss: 0.0040

# %%
# Calculate predicted stock prices for the last 'horizon' steps
time = data['Date'][-n_test:][-horizon:]
data1 = close[-n_test:][-horizon:]
finalpredicted_stock_price = []
pred = close[-n_test - 1]

# Calculate stock prices based on predictions
for i in range(horizon):
    pred = data1[i] * (1 + predictions[i])
    finalpredicted_stock_price.append(pred)

# Convert `data1` (test close prices) to ratechg
data1_pct_chg = np.diff(data1) / data1[:-1] * 100  # Calculate percentage change
test_ratechg = data1_pct_chg * 0.01  # Scale by 0.01 to match ratechg format

# Convert `finalpredicted_stock_price` (predicted close prices) to ratechg
predicted_pct_chg = np.diff(finalpredicted_stock_price) / np.array(finalpredicted_stock_price[:-1]) * 100
predicted_ratechg = predicted_pct_chg * 0.01  # Scale by 0.01

# %%
# Evaluate metrics
print('MSE MAE')
evaluation_metric(test_ratechg[:horizon-1], predicted_ratechg)
# Out:
# MSE MAE
# 0.000084 0.005724

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(time, data1, label='Actual Stock Price')
plt.plot(time, finalpredicted_stock_price, label='Predicted Stock Price')
plt.title('Petrobras Stock Price Prediction')
plt.xlabel('Time', fontsize=12, verticalalignment='top')
plt.ylabel('Close', fontsize=14, horizontalalignment='center')
plt.legend()
plt.show()

# %% [markdown]
# # Horizon 22

# %%
horizon = 22

# %%
# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-horizon:]  # Use the last 'horizon' data points in test for prediction
testy = ratechg[-n_test:][-horizon:]  # Last 'horizon' rate changes for evaluation

# %%
# Predicting
predictions = PredictWithData(trainX, trainy, valX, valy, testX)
# Out:
# Epoch 0 | Train Loss: 0.0553 | Validation Loss: 0.0173
# Epoch 10 | Train Loss: 0.0045 | Validation Loss: 0.0018
# Epoch 20 | Train Loss: 0.0021 | Validation Loss: 0.0008
# Epoch 30 | Train Loss: 0.0017 | Validation Loss: 0.0012
# Epoch 40 | Train Loss: 0.0013 | Validation Loss: 0.0007
# Epoch 50 | Train Loss: 0.0012 | Validation Loss: 0.0007
# Epoch 60 | Train Loss: 0.0011 | Validation Loss: 0.0007
# Epoch 70 | Train Loss: 0.0010 | Validation Loss: 0.0006
# Epoch 80 | Train Loss: 0.0010 | Validation Loss: 0.0006
# Epoch 90 | Train Loss: 0.0009 | Validation Loss: 0.0006

# %%
# Calculate predicted stock prices for the last 'horizon' steps
time = data['Date'][-n_test:][-horizon:]
data1 = close[-n_test:][-horizon:]
finalpredicted_stock_price = []
pred = close[-n_test - 1]

# Calculate stock prices based on predictions
for i in range(horizon):
    pred = data1[i] * (1 + predictions[i])
    finalpredicted_stock_price.append(pred)

# Convert `data1` (test close prices) to ratechg
data1_pct_chg = np.diff(data1) / data1[:-1] * 100  # Calculate percentage change
test_ratechg = data1_pct_chg * 0.01  # Scale by 0.01 to match ratechg format

# Convert `finalpredicted_stock_price` (predicted close prices) to ratechg
predicted_pct_chg = np.diff(finalpredicted_stock_price) / np.array(finalpredicted_stock_price[:-1]) * 100
predicted_ratechg = predicted_pct_chg * 0.01  # Scale by 0.01

# %%
# Evaluate metrics
print('MSE MAE')
evaluation_metric(test_ratechg[:horizon-1], predicted_ratechg)
# Out:
# MSE MAE
# 0.000058 0.005221

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(time, data1, label='Actual Stock Price')
plt.plot(time, finalpredicted_stock_price, label='Predicted Stock Price')
plt.title('Petrobras Stock Price Prediction')
plt.xlabel('Time', fontsize=12, verticalalignment='top')
plt.ylabel('Close', fontsize=14, horizontalalignment='center')
plt.legend()
plt.show()

# %% [markdown]
# # Horizon 50

# %%
horizon = 50

# %%
# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-horizon:]  # Use the last 'horizon' data points in test for prediction
testy = ratechg[-n_test:][-horizon:]  # Last 'horizon' rate changes for evaluation

# %%
# Predicting
predictions = PredictWithData(trainX, trainy, valX, valy, testX)
# Out:
# Epoch 0 | Train Loss: 0.0934 | Validation Loss: 0.0297
# Epoch 10 | Train Loss: 0.0022 | Validation Loss: 0.0029
# Epoch 20 | Train Loss: 0.0037 | Validation Loss: 0.0027
# Epoch 30 | Train Loss: 0.0016 | Validation Loss: 0.0016
# Epoch 40 | Train Loss: 0.0017 | Validation Loss: 0.0020
# Epoch 50 | Train Loss: 0.0014 | Validation Loss: 0.0014
# Epoch 60 | Train Loss: 0.0013 | Validation Loss: 0.0011
# Epoch 70 | Train Loss: 0.0012 | Validation Loss: 0.0011
# Epoch 80 | Train Loss: 0.0011 | Validation Loss: 0.0009
# Epoch 90 | Train Loss: 0.0010 | Validation Loss: 0.0009

# %%
# Calculate predicted stock prices for the last 'horizon' steps
time = data['Date'][-n_test:][-horizon:]
data1 = close[-n_test:][-horizon:]
finalpredicted_stock_price = []
pred = close[-n_test - 1]

# Calculate stock prices based on predictions
for i in range(horizon):
    pred = data1[i] * (1 + predictions[i])
    finalpredicted_stock_price.append(pred)

# Convert `data1` (test close prices) to ratechg
data1_pct_chg = np.diff(data1) / data1[:-1] * 100  # Calculate percentage change
test_ratechg = data1_pct_chg * 0.01  # Scale by 0.01 to match ratechg format

# Convert `finalpredicted_stock_price` (predicted close prices) to ratechg
predicted_pct_chg = np.diff(finalpredicted_stock_price) / np.array(finalpredicted_stock_price[:-1]) * 100
predicted_ratechg = predicted_pct_chg * 0.01  # Scale by 0.01

# %%
# Evaluate metrics
print('MSE MAE')
evaluation_metric(test_ratechg[:horizon-1], predicted_ratechg)
# Out:
# MSE MAE
# 0.000067 0.004805

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(time, data1, label='Actual Stock Price')
plt.plot(time, finalpredicted_stock_price, label='Predicted Stock Price')
plt.title('Petrobras Stock Price Prediction')
plt.xlabel('Time', fontsize=12, verticalalignment='top')
plt.ylabel('Close', fontsize=14, horizontalalignment='center')
plt.legend()
plt.show()

# %% [markdown]
# # Horizon 100

# %%
horizon = 50

# %%
# Prepare labels for train, validation, and test
trainX, trainy = train_data, ratechg[:-(n_test + n_val)]
valX, valy = val_data, ratechg[-(n_test + n_val):-n_test]
testX = test_data[-horizon:]  # Use the last 'horizon' data points in test for prediction
testy = ratechg[-n_test:][-horizon:]  # Last 'horizon' rate changes for evaluation

# %%
# Predicting
predictions = PredictWithData(trainX, trainy, valX, valy, testX)
# Out:
# Epoch 0 | Train Loss: 0.2247 | Validation Loss: 0.1908
# Epoch 10 | Train Loss: 0.0134 | Validation Loss: 0.0146
# Epoch 20 | Train Loss: 0.0034 | Validation Loss: 0.0021
# Epoch 30 | Train Loss: 0.0032 | Validation Loss: 0.0011
# Epoch 40 | Train Loss: 0.0015 | Validation Loss: 0.0014
# Epoch 50 | Train Loss: 0.0014 | Validation Loss: 0.0010
# Epoch 60 | Train Loss: 0.0012 | Validation Loss: 0.0009
# Epoch 70 | Train Loss: 0.0011 | Validation Loss: 0.0008
# Epoch 80 | Train Loss: 0.0011 | Validation Loss: 0.0008
# Epoch 90 | Train Loss: 0.0010 | Validation Loss: 0.0007

# %%
# Calculate predicted stock prices for the last 'horizon' steps
time = data['Date'][-n_test:][-horizon:]
data1 = close[-n_test:][-horizon:]
finalpredicted_stock_price = []
pred = close[-n_test - 1]

# Calculate stock prices based on predictions
for i in range(horizon):
    pred = data1[i] * (1 + predictions[i])
    finalpredicted_stock_price.append(pred)

# Convert `data1` (test close prices) to ratechg
data1_pct_chg = np.diff(data1) / data1[:-1] * 100  # Calculate percentage change
test_ratechg = data1_pct_chg * 0.01  # Scale by 0.01 to match ratechg format

# Convert `finalpredicted_stock_price` (predicted close prices) to ratechg
predicted_pct_chg = np.diff(finalpredicted_stock_price) / np.array(finalpredicted_stock_price[:-1]) * 100
predicted_ratechg = predicted_pct_chg * 0.01  # Scale by 0.01

# %%
# Evaluate metrics
print('MSE MAE')
evaluation_metric(test_ratechg[:horizon-1], predicted_ratechg)
# Out:
# MSE MAE
# 0.000031 0.004339

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(time, data1, label='Actual Stock Price')
plt.plot(time, finalpredicted_stock_price, label='Predicted Stock Price')
plt.title('Petrobras Stock Price Prediction')
plt.xlabel('Time', fontsize=12, verticalalignment='top')
plt.ylabel('Close', fontsize=14, horizontalalignment='center')
plt.legend()
plt.show()
